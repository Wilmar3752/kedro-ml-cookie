# %% [markdown]
# # Explore Raw Data
#
# Load datasets directly from the Kedro catalog without running any pipeline.

# %%
from pathlib import Path
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project

bootstrap_project(Path.cwd().parent)

session = KedroSession.create()
catalog = session.load_context().catalog

# %% [markdown]
# ## Titanic (binary classification)

# %%
titanic = catalog.load("titanic_raw")
print(titanic.shape)
titanic.head()

# %%
titanic.info()

# %%
titanic.describe()

# %%
titanic.isnull().mean().sort_values(ascending=False)

# %% [markdown]
# ## California Housing (regression)

# %%
california = catalog.load("california_raw")
print(california.shape)
california.head()

# %%
california.info()

# %%
california.describe()

# %%
california.isnull().mean().sort_values(ascending=False)
